# %% [markdown]
# # Exploratory data analysis -flats  rental offerts in Wrocław analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data_olx = pd.read_csv('data_olx.csv', sep=';')
data_olx
# Out:
#                                                    Name  Localisation  Price  \
# 0     Blisko Uniw. Ekonom. i Medyczn WYNAJMĘ 2-pok m...        Krzyki   2490
# 1          wynajmę 2 pokojowe mieszkanie Wrocław krzyki        Krzyki   2500
# 2     Mieszkanie 46m z ogródkiem Wrocław ul. Rybnick...        Krzyki   3000
# 3     2 Pokoje, Klimatyzacja, Garaż, Tarnogaj, Dostę...        Krzyki   2900
# 4                           Lokum Di Trevi, Międzyleska        Krzyki   3250
# ...                                                 ...           ...    ...
# 1236      Mieszkanie - 2 pokoje, osobna kuchnia, balkon     Psie Pole   2600
# 1237                   Mieszkanie blisko rynku /Wrocław  Stare Miasto   2850
# 1238    Kawalerka 33m2 od zaraz, Wrocław ul. Skarbowców        Krzyki   2200
# 1239  Centrum Wrocławia/ pokoje dla pracowników przy...  Stare Miasto    650
# 1240                          mieszkanie do wynajecia !        Krzyki   2200
#
#       Area
# 0     39.0
# 1     50.0
# 2     46.0
# 3     45.0
# 4     47.5
# ...    ...
# 1236  49.0
# 1237  54.0
# 1238  33.0
# 1239  55.0
# 1240  30.0
#
# [1241 rows x 4 columns]
